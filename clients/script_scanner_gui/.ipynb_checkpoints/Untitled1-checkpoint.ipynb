# %%
import numpy as np
(dds, ttl, channels) = np.load('example_pulse_sequence_info_nlr.npy')

# %%
dds_nlr = [tuple([el[0], float(el[1]), float(el[2])]) for el in dds]

# %%
np.save('example_pulse_sequence_info.npy', (dds_nlr, ttl, channels))

# %%
dds
# Out:
# [('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 226.13726226290157, -6.998168917372396),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.01476223813714, -6.998168917372396),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
# ...

# %%
dds_nlr
# Out:
# [('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 0.0, -63.0),
#  ('729vert', 226.13726226290157, -6.998168917372396),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.13726226290157, -63.0),
#  ('729vert', 226.01476223813714, -6.998168917372396),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
#  ('729vert', 226.01476223813714, -63.0),
# ...

# %%
len(dds)
# Out:
# 1106
