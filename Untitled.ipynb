# %%
# %matplotlib notebook

# %%
from matplotlib import pyplot as plt

# %%
data = [1,2,3,5,8,13]
plt.figure()
plt.plot(data)
plt.show()
plt.figure()
plt.plot([1,2,3])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
